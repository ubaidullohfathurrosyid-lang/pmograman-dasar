# %% [markdown]
# <a href="https://colab.research.google.com/github/ubaidullohfathurrosyid-lang/pmograman-dasar/blob/main/TUGAS%20PERTEMUAN%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS PERTEMUAN 4

# %%
print("="*30)
print("SELAMAT DATANG DI KAFE GEMINI")
print("="*30)
print("Menu Makanan & Minuman:")
print("1. Kopi Hitam  - Rp 12.000")
print("2. Teh Manis   - Rp 8.000")
print("3. Roti Bakar  - Rp 15.000")
print("4. Mie Instan  - Rp 10.000")
print("="*30)

# Pilihan menu
pilihan = int(input("Silakan masukkan nomor pilihan Anda (1-4): "))

nama_pesanan = ""
harga = 0

if pilihan == 1:
    nama_pesanan = "Kopi Hitam"
    harga = 12000
elif pilihan == 2:
    nama_pesanan = "Teh Manis"
    harga = 8000
elif pilihan == 3:
    nama_pesanan = "Roti Bakar"
    harga = 15000
elif pilihan == 4:
    nama_pesanan = "Mie Instan"
    harga = 10000
else:
    print("Maaf, pilihan menu tidak valid. Silakan jalankan ulang program.")

if harga > 0:
    print("="*30)
    print(f"Anda memesan: {nama_pesanan} dengan harga Rp {harga}")

    jumlah = int(input("Masukkan jumlah pesanan: "))
    total_harga = harga * jumlah

    # Pilihan diskon
    print("\nKategori Diskon:")
    print("1. Diskon 70%")
    print("2. Diskon 50%")
    print("3. Diskon 30%")
    print("4. Tidak ada diskon")

    pilih_diskon = int(input("Pilih kategori diskon (1-4): "))

    if pilih_diskon == 1:
        diskon = 0.70
    elif pilih_diskon == 2:
        diskon = 0.50
    elif pilih_diskon == 3:
        diskon = 0.30
    else:
        diskon = 0.0

    potongan = total_harga * diskon
    total_bayar = total_harga - potongan

    print(f"\nTotal Harga Sebelum Diskon: Rp {total_harga}")
    print(f"Diskon: {int(diskon*100)}% (Rp {int(potongan)})")
    print(f"Total Bayar Sesudah Diskon: Rp {int(total_bayar)}")

    uang_dibayar = int(input("\nMasukkan jumlah uang Anda: Rp "))

    if uang_dibayar >= total_bayar:
        kembalian = uang_dibayar - total_bayar
        print("\n--- Struk Pembayaran ---")
        print(f"Pesanan Anda  : {nama_pesanan}")
        print(f"Jumlah        : {jumlah}")
        print(f"Total Harga   : Rp {int(total_harga)}")
        print(f"Diskon        : {int(diskon*100)}% (Rp {int(potongan)})")
        print(f"Total Bayar   : Rp {int(total_bayar)}")
        print(f"Uang Dibayar  : Rp {uang_dibayar}")
        print(f"Kembalian     : Rp {int(kembalian)}")
        print("-------------------------")
        print("Terima kasih telah berbelanja!")

    else:
        kekurangan = total_bayar - uang_dibayar
        print(f"Maaf, uang Anda kurang sebesar Rp {int(kekurangan)}")

print("="*30)
# Out:
# ==============================
# SELAMAT DATANG DI KAFE GEMINI
# ==============================
# Menu Makanan & Minuman:
# 1. Kopi Hitam  - Rp 12.000
# 2. Teh Manis   - Rp 8.000
# 3. Roti Bakar  - Rp 15.000
# 4. Mie Instan  - Rp 10.000
# ==============================
# Silakan masukkan nomor pilihan Anda (1-4): 3
# ==============================
# Anda memesan: Roti Bakar dengan harga Rp 15000
# Masukkan jumlah pesanan: 5
#
# Kategori Diskon:
# 1. Diskon 70%
# 2. Diskon 50%
# 3. Diskon 30%
# 4. Tidak ada diskon
# Pilih kategori diskon (1-4): 2
#
# Total Harga Sebelum Diskon: Rp 75000
# Diskon: 50% (Rp 37500)
# Total Bayar Sesudah Diskon: Rp 37500
#
# Masukkan jumlah uang Anda: Rp 49000
#
# --- Struk Pembayaran ---
# Pesanan Anda  : Roti Bakar
# Jumlah        : 5
# Total Harga   : Rp 75000
# Diskon        : 50% (Rp 37500)
# Total Bayar   : Rp 37500
# Uang Dibayar  : Rp 49000
# Kembalian     : Rp 11500
# -------------------------
# Terima kasih telah berbelanja!
# ==============================

# %%
print("="*30)
print("SELAMAT DATANG DI KAFE GEMINI")
print("="*30)
print("Menu Makanan & Minuman:")
print("1. Kopi Hitam  - Rp 12.000")
print("2. Teh Manis   - Rp 8.000")
print("3. Roti Bakar  - Rp 15.000")
print("4. Mie Instan  - Rp 10.000")
print("="*30)

# Pilihan menu
pilihan = int(input("Silakan masukkan nomor pilihan Anda (1-4): "))

nama_pesanan = ""
harga = 0

if pilihan == 1:
    nama_pesanan = "Kopi Hitam"
    harga = 12000
elif pilihan == 2:
    nama_pesanan = "Teh Manis"
    harga = 8000
elif pilihan == 3:
    nama_pesanan = "Roti Bakar"
    harga = 15000
elif pilihan == 4:
    nama_pesanan = "Mie Instan"
    harga = 10000
else:
    print("Maaf, pilihan menu tidak valid. Silakan jalankan ulang program.")


if harga > 0:
    print("="*30)
    print(f"Anda memesan: {nama_pesanan} dengan harga Rp {harga}")

    jumlah = int(input("Masukkan jumlah pesanan: "))
    total_harga = harga * jumlah

    # Pilihan diskon
    print("\nKategori Diskon:")
    print("1. Diskon 70%")
    print("2. Diskon 50%")
    print("3. Diskon 30%")
    print("4. Tidak ada diskon")

    pilih_diskon = int(input("Pilih kategori diskon (1-4): "))

    if pilih_diskon == 1:
        diskon = 0.70
    elif pilih_diskon == 2:
        diskon = 0.50
    elif pilih_diskon == 3:
        diskon = 0.30
    else:
        diskon = 0.0

    potongan = total_harga * diskon
    total_bayar = total_harga - potongan

    print(f"\nTotal Harga Sebelum Diskon: Rp {total_harga}")
    print(f"Diskon: {int(diskon*100)}% (Rp {int(potongan)})")
    print(f"Total Bayar Sesudah Diskon: Rp {int(total_bayar)}")

    uang_dibayar = int(input("\nMasukkan jumlah uang Anda: Rp "))

    if uang_dibayar >= total_bayar:
        kembalian = uang_dibayar - total_bayar
        print("\n--- Struk Pembayaran ---")
        print(f"Pesanan Anda  : {nama_pesanan}")
        print(f"Jumlah        : {jumlah}")
        print(f"Total Harga   : Rp {int(total_harga)}")
        print(f"Diskon        : {int(diskon*100)}% (Rp {int(potongan)})")
        print(f"Total Bayar   : Rp {int(total_bayar)}")
        print(f"Uang Dibayar  : Rp {uang_dibayar}")
        print(f"Kembalian     : Rp {int(kembalian)}")
        print("-------------------------")
        print("Terima kasih telah berbelanja!")
    else:
        kekurangan = total_bayar - uang_dibayar
        print(f"Maaf, uang Anda kurang sebesar Rp {int(kekurangan)}")

print("="*30)
# Out:
# ==============================
# SELAMAT DATANG DI KAFE GEMINI
# ==============================
# Menu Makanan & Minuman:
# 1. Kopi Hitam  - Rp 12.000
# 2. Teh Manis   - Rp 8.000
# 3. Roti Bakar  - Rp 15.000
# 4. Mie Instan  - Rp 10.000
# ==============================
# Silakan masukkan nomor pilihan Anda (1-4): 1
# ==============================
# Anda memesan: Kopi Hitam dengan harga Rp 12000
# Masukkan jumlah pesanan: 5
#
# Kategori Diskon:
# 1. Diskon 70%
# 2. Diskon 50%
# 3. Diskon 30%
# 4. Tidak ada diskon
# Pilih kategori diskon (1-4): 3
#
# Total Harga Sebelum Diskon: Rp 60000
# Diskon: 30% (Rp 18000)
# Total Bayar Sesudah Diskon: Rp 42000
#
# Masukkan jumlah uang Anda: Rp 150000
#
# --- Struk Pembayaran ---
# Pesanan Anda  : Kopi Hitam
# Jumlah        : 5
# Total Harga   : Rp 60000
# Diskon        : 30% (Rp 18000)
# Total Bayar   : Rp 42000
# Uang Dibayar  : Rp 150000
# Kembalian     : Rp 108000
# -------------------------
# Terima kasih telah berbelanja!
# ==============================

# %%
print("="*30)
print("SELAMAT DATANG DI KAFE GEMINI")
print("="*30)
print("Menu Makanan & Minuman:")
print("1. Kopi Hitam  - Rp 12.000")
print("2. Teh Manis   - Rp 8.000")
print("3. Roti Bakar  - Rp 15.000")
print("4. Mie Instan  - Rp 10.000")
print("="*30)

# Pilihan menu
pilihan = int(input("Silakan masukkan nomor pilihan Anda (1-4): "))

nama_pesanan = ""
harga = 0

if pilihan == 1:
    nama_pesanan = "Kopi Hitam"
    harga = 12000
elif pilihan == 2:
    nama_pesanan = "Teh Manis"
    harga = 8000
elif pilihan == 3:
    nama_pesanan = "Roti Bakar"
    harga = 15000
elif pilihan == 4:
    nama_pesanan = "Mie Instan"
    harga = 10000
else:
    print("Maaf, pilihan menu tidak valid. Silakan jalankan ulang program.")

if harga > 0:
    print("="*30)
    print(f"Anda memesan: {nama_pesanan} dengan harga Rp {harga}")

    jumlah = int(input("Masukkan jumlah pesanan: "))
    total_harga = harga * jumlah

    # Pilihan diskon
    print("\nKategori Diskon:")
    print("1. Diskon 70%")
    print("2. Diskon 50%")
    print("3. Diskon 30%")
    print("4. Tidak ada diskon")

    pilih_diskon = int(input("Pilih kategori diskon (1-4): "))

    if pilih_diskon == 1:
        diskon = 0.70
    elif pilih_diskon == 2:
        diskon = 0.50
    elif pilih_diskon == 3:
        diskon = 0.30
    else:
        diskon = 0.0

    potongan = total_harga * diskon
    total_bayar = total_harga - potongan

    print(f"\nTotal Harga Sebelum Diskon: Rp {total_harga}")
    print(f"Diskon: {int(diskon*100)}% (Rp {int(potongan)})")
    print(f"Total Bayar Sesudah Diskon: Rp {int(total_bayar)}")

    uang_dibayar = int(input("\nMasukkan jumlah uang Anda: Rp "))

    if uang_dibayar >= total_bayar:
        kembalian = uang_dibayar - total_bayar
        print("\n--- Struk Pembayaran ---")
        print(f"Pesanan Anda  : {nama_pesanan}")
        print(f"Jumlah        : {jumlah}")
        print(f"Total Harga   : Rp {int(total_harga)}")
        print(f"Diskon        : {int(diskon*100)}% (Rp {int(potongan)})")
        print(f"Total Bayar   : Rp {int(total_bayar)}")
        print(f"Uang Dibayar  : Rp {uang_dibayar}")
        print(f"Kembalian     : Rp {int(kembalian)}")
        print("-------------------------")
        print("Terima kasih telah berbelanja!")
    else:
        kekurangan = total_bayar - uang_dibayar
        print(f"Maaf, uang Anda kurang sebesar Rp {int(kekurangan)}")

print("="*30)
# Out:
# ==============================
# SELAMAT DATANG DI KAFE GEMINI
# ==============================
# Menu Makanan & Minuman:
# 1. Kopi Hitam  - Rp 12.000
# 2. Teh Manis   - Rp 8.000
# 3. Roti Bakar  - Rp 15.000
# 4. Mie Instan  - Rp 10.000
# ==============================
# Silakan masukkan nomor pilihan Anda (1-4): 2
# ==============================
# Anda memesan: Teh Manis dengan harga Rp 8000
# Masukkan jumlah pesanan: 6
#
# Kategori Diskon:
# 1. Diskon 70%
# 2. Diskon 50%
# 3. Diskon 30%
# 4. Tidak ada diskon
# Pilih kategori diskon (1-4): 1
#
# Total Harga Sebelum Diskon: Rp 48000
# Diskon: 70% (Rp 33600)
# Total Bayar Sesudah Diskon: Rp 14400
#
# Masukkan jumlah uang Anda: Rp 200000
#
# --- Struk Pembayaran ---
# Pesanan Anda  : Teh Manis
# Jumlah        : 6
# Total Harga   : Rp 48000
# Diskon        : 70% (Rp 33600)
# Total Bayar   : Rp 14400
# Uang Dibayar  : Rp 200000
# Kembalian     : Rp 185600
# -------------------------
# Terima kasih telah berbelanja!
# ==============================
